# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("equipment_anomaly_data.csv")
df
# Out:
#       temperature   pressure  vibration   humidity   equipment       location  \
# 0       58.180180  25.029278   0.606516  45.694907     Turbine        Atlanta
# 1       75.740712  22.954018   2.338095  41.867407  Compressor        Chicago
# 2       71.358594  27.276830   1.389198  58.954409     Turbine  San Francisco
# 3       71.616985  32.242921   1.770690  40.565138        Pump        Atlanta
# 4       66.506832  45.197471   0.345398  43.253795        Pump       New York
# ...           ...        ...        ...        ...         ...            ...
# 7667    65.711521  37.505934   2.030521  49.331471        Pump       New York
# 7668    63.005855  45.164234   1.264585  61.905390        Pump       New York
# 7669    72.029230  34.757896   1.709046  49.972917        Pump        Atlanta
# 7670   107.086485  23.754114   1.142522  23.967977  Compressor        Atlanta
# 7671    28.468054  66.588978   4.677368  79.670225     Turbine        Chicago
#
#       faulty
# 0        0.0
# ...

# %% [markdown]
# # First Look into the data before analysis

# %%
any_nans = np.sum(df.isna().to_numpy().flatten())
print(f"The dataset contains {any_nans} nans.")
# Out:
# The dataset contains 0 nans.

# %%
df.loc[:, "faulty_binary"] = df.loc[:, "faulty"] != 0 # Turn into binary True/ False

nr_faulty = np.sum(df.faulty_binary == True)
nr_working = np.sum(df.faulty_binary == False)
print(f"Dataset contains entries for {df.shape[0]} machines. {nr_faulty}({nr_faulty/df.shape[0]:.2%}) are faulty and {nr_working}({nr_working/df.shape[0]:.2%}) are functioning.")
# Out:
# Dataset contains entries for 7672 machines. 767(10.00%) are faulty and 6905(90.00%) are functioning.

# %%
df_grouped = df.groupby(["equipment", "faulty_binary"]).count().iloc[:, 0]
df_grouped = df_grouped.rename("Count")
df_grouped = df_grouped.reset_index()

fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot()
sns.barplot(x="equipment", y="Count", hue="faulty_binary", data=df_grouped, ax = ax)
ax.set_title("Count of equipments, grouped by faulty or not")
plt.show()

# %%
df_grouped = df.groupby(["location", "faulty_binary"]).count().iloc[:, 0]
df_grouped = df_grouped.rename("Count")
df_grouped = df_grouped.reset_index()

fig = plt.figure(figsize = (10, 8))
ax = fig.add_subplot()
sns.barplot(x="location", y="Count", hue="faulty_binary", data=df_grouped, ax = ax)
ax.set_title("Count of equipments at locations, grouped by faulty or not")
plt.show()

# %%
df_grouped = df.groupby(["location", "equipment", "faulty_binary"]).count().iloc[:, 0]
df_grouped = df_grouped.rename("Count")
df_grouped = df_grouped.reset_index()
df_grouped

fig = plt.figure(figsize = (20, 10))

ax = fig.add_subplot(1, 2, 1)
matrix = df_grouped.loc[df_grouped["faulty_binary"] == True].drop(columns = ["faulty_binary"]).pivot(columns = ["equipment"], index = ["location"])
matrix.columns = [i[1] for i in matrix.columns]
matrix.columns.name = "equpiment"
sns.heatmap(matrix, ax = ax, annot = True, fmt = "_")
ax.set_title("Count of non-faulty equipment per location")

ax = fig.add_subplot(1, 2, 2)
matrix = df_grouped.loc[df_grouped["faulty_binary"] == False].drop(columns = ["faulty_binary"]).pivot(columns = ["equipment"], index = ["location"])
matrix.columns = [i[1] for i in matrix.columns]
matrix.columns.name = "equpiment"
sns.heatmap(matrix, ax = ax, annot = True, fmt = "_")
ax.set_title("Count of faulty equipment per location")

fig.suptitle("Number of faulty and non-faulty equipment does not depend strongly on specific location or equipment. The aspect of the location will be ignored in the analysis")
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

anova_df = df.loc[:, ("location", "equipment", "faulty")]

model = ols('faulty ~ C(location) + C(equipment) + C(location):C(equipment)', data=anova_df).fit()
anova_result = sm.stats.anova_lm(model, type=2)
anova_result
# Out:
#                               df      sum_sq   mean_sq         F    PR(>F)
# C(location)                  4.0    0.552184  0.138046  1.535164  0.189006
# C(equipment)                 2.0    0.001921  0.000960  0.010679  0.989378
# C(location):C(equipment)     8.0    1.228466  0.153558  1.707671  0.091226
# Residual                  7657.0  688.537425  0.089923       NaN       NaN

# %% [markdown]
# # Start Analysis-Prep

# %%
df_analysis = df.copy()# .drop(columns = ["faulty"])
location_labels, location_levels = df_analysis.loc[:, "location"].factorize()
equipment_labels, equipment_levels = df_analysis.loc[:, "equipment"].factorize()
# df_analysis.loc[:, "location_factorized"] = location_labels
# df_analysis.loc[:, "equipment_factorized"] = equipment_labels
df_analysis.drop(inplace = True, columns = ["equipment", "location", "faulty"])

Y = df_analysis.loc[:, "faulty_binary"]
X = df_analysis.drop(columns = ["faulty_binary"])

# Np imputation/ removal required as no Nans. Standardize X
X = (X - np.mean(X, axis = 0))/np.std(X, axis = 0)
X["equipment"] = equipment_labels

# %%
X
# Out:
#       temperature  pressure  vibration  humidity  equipment
# 0       -0.786610 -1.031582  -1.379925 -0.364984          0
# 1        0.297440 -1.231493   0.996943 -0.688233          1
# 2        0.026922 -0.815074  -0.305569  0.754840          0
# 3        0.042873 -0.336688   0.218089 -0.798215          2
# 4       -0.272588  0.911232  -1.738352 -0.571147          2
# ...           ...       ...        ...       ...        ...
# 7667    -0.321684  0.170301   0.574749 -0.057860          2
# 7668    -0.488711  0.908030  -0.476621  1.004063          2
# 7669     0.068322 -0.094419   0.133473 -0.003687          2
# 7670     2.232483 -1.154420  -0.644172 -2.199919          1
# 7671    -2.620805  2.971889   4.207969  2.504382          0
#
# [7672 rows x 5 columns]

# %% [markdown]
# ### Dimensionality reduction

# %%
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from umap import UMAP

import torch
import torch.nn as nn

# %%
class Autoencoder(nn.Module):
    def __init__(self, In_Features, Out_Features, lr = 1e-3):
        super().__init__()
        self.In_Features = In_Features
        self.Out_Features = Out_Features

        ############################### encoder ######################################
        encoder_layers = []
        # Input
        encoder_layers.extend([nn.Linear(self.In_Features, self.In_Features-1), nn.BatchNorm1d(self.In_Features-1), nn.LeakyReLU()])
        last_nodes = self.In_Features-1
        # Hidden
        for i in np.arange(self.In_Features-1, self.Out_Features+1, -1):
            encoder_layers.extend([nn.Linear(i, i-1), nn.BatchNorm1d(i-1), nn.LeakyReLU()])
            last_nodes = i-1
        # Output
        encoder_layers.extend([nn.Linear(last_nodes, self.Out_Features), nn.BatchNorm1d(self.Out_Features), nn.LeakyReLU()])
        self.encoder = nn.Sequential(*encoder_layers)


        ############################ decoder ###########################################
        decoder_layers = []
        # Input
        decoder_layers.extend([nn.Linear(self.Out_Features, self.Out_Features+1), nn.BatchNorm1d(self.Out_Features+1), nn.LeakyReLU()])
        last_nodes = self.Out_Features+1
        # Hidden
        for i in np.arange(self.Out_Features+1, self.In_Features-1, +1):
            decoder_layers.extend([nn.Linear(i, i+1), nn.BatchNorm1d(i+1), nn.LeakyReLU()])
            last_nodes = i+1
        # Output
        decoder_layers.extend([nn.Linear(last_nodes, self.In_Features)])
        self.decoder = nn.Sequential(*decoder_layers)


        ############# parameters ##############################################################
        self.loss = nn.MSELoss()
        self.optimizer = torch.optim.Adam(self.parameters(), lr = lr)

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

    def fit(self, x, epochs = 30, verbose = False, print_Score = False, val_size = 0.2):
        x = torch.tensor(x, dtype = torch.float32)
        train, val = train_test_split(x, test_size = val_size)
        if verbose:
            for epoch in tqdm(range(epochs), desc = "Fitting autoencoder"):
                self.optimizer.zero_grad()
                x_pred = self.forward(train)
                loss = self.loss(x_pred, train)
                loss.backward()
                self.optimizer.step()

        else:
            for epoch in range(epochs):
                self.optimizer.zero_grad()
                x_pred = self.forward(train)
                loss = self.loss(x_pred, train)
                loss.backward()
                self.optimizer.step()

        if print_Score:
            with torch.no_grad():
                x_pred = self.forward(train)
                final_score = self.loss(x_pred, train)
                print(f"Train Autoencoder MSE: {final_score.detach():.10f}")
                x_pred = self.forward(val)
                final_score = self.loss(x_pred, val)
                print(f"Valid Autoencoder MSE: {final_score.detach():.10f}")

    def transform(self, x):
        with torch.no_grad():
            x = torch.tensor(x, dtype = torch.float32)
            embedded = self.encoder(x)
            return embedded.numpy()


class NoTransform:
    def __init__(self):
        "nothing"
    def fit(self, x):
        "nothing"
    def transform(self, x):
        return x

# Linear dimensionality rduction: PCA
pca = PCA(n_components = 3)
# Non-Linear dimensionality reduction 1: UMAP
umap = UMAP(n_components = 3)
# Non-liner dimensitonality reduciton 2: Autoencoder
autoencoder = Autoencoder(In_Features = X.shape[1], Out_Features = 3)
# moch-reducer
mock = NoTransform()

# %% [markdown]
# ## Models to compare

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

# %%
unique_labels, class_counts = np.unique(df.loc[:, "faulty"], return_counts = True)

total_samples = df.shape[0]
num_classes = len(class_counts)
class_weights = total_samples / (num_classes * class_counts)
class_weights = torch.tensor(class_weights / np.sum(class_weights)).type(torch.float)
print(class_weights)
# Out:
# tensor([0.1000, 0.9000])

# %%
class MLP(nn.Module):
    def __init__(self, in_features, lr = 1e-4, weights = None):
        super().__init__()

        if not (weights is None):
            self.train_loss = nn.CrossEntropyLoss(weight = weights)
        else:
            self.train_loss = nn.CrossEntropyLoss()
        self.val_loss = nn.CrossEntropyLoss()

        self.in_features = in_features

        self.fc1 = self.Linear_Layer(self.in_features, 100)
        self.fc2 = self.Linear_Layer(100, 50)
        self.fc3 = self.Linear_Layer(50, 10)
        self.out_layer = nn.Linear(10, 2)

        self.optimizer = torch.optim.Adam(self.parameters(), lr = lr)
        self.sigmoid = nn.Sigmoid()

    def Linear_Layer(self, in_features, out_features):
        layer = nn.Sequential(
            nn.Linear(in_features, out_features),
            nn.BatchNorm1d(out_features),
            nn.ReLU(),
            nn.Dropout(0.2)
        )
        return layer

    def forward(self, x):
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        y_pred = self.sigmoid(self.out_layer(x))
        return y_pred

    def fit(self, x_train, y_train, epochs = 30, verbose = False):
        x_train = torch.tensor(x_train, dtype = torch.float32)
        y_train = torch.tensor(y_train, dtype = torch.long)
        if verbose:
            for epoch in tqdm(range(epochs), desc = "Fitting autoencoder"):
                self.optimizer.zero_grad()
                y_pred = self.forward(x_train)
                loss = self.train_loss(y_pred, y_train)
                loss.backward()
                self.optimizer.step()
        else:
            for epoch in range(epochs):
                self.optimizer.zero_grad()
                y_pred = self.forward(x_train)
                loss = self.train_loss(y_pred, y_train)
                loss.backward()
                self.optimizer.step()
            

    def eval(self, x_val, y_val):
        x_val = torch.tensor(x_val, dtype = torch.float32)
        y_val = torch.tensor(y_val, dtype = torch.long)
        with torch.no_grad():
            y_pred = self.forward(x_val)
            final_score = self.val_loss(y_pred, y_val)
            print(f"Validation CE Loss: {final_score.detach():.10f}")

    def predict(self, x_test, as_text = False):
        x_test = torch.tensor(x_test, dtype = torch.float32)
        with torch.no_grad():
            y_pred = torch.argmax(self.forward(x_test), dim = 1)
            if as_text:
                y_pred = np.array(["Faulty" if i == 1 else "Not faulty" for i in y_pred ])
            return y_pred.numpy()
        

def make_mlp(mode, in_features, *args, **kwargs):
    if mode == "Weighted":
        return MLP(in_features = in_features, weights = class_weights)
    else:
        return MLP(in_features = in_features)

def make_knc(mode, *args, **kwargs):
    if mode == "Weighted":
        return  KNeighborsClassifier(n_neighbors=5, weights = "distance")
    else:
        return KNeighborsClassifier(n_neighbors=5)

def make_rfc(mode, *args, **kwargs):
    if mode == "Weighted":
        return RandomForestClassifier(n_estimators=100, class_weight = {i: class_weights[i] for i in range(len(class_weights))})
    else:
        return RandomForestClassifier(n_estimators=100)

def make_svc(mode, *args, **kwargs):
    if mode == "Weighted":
        return SVC(class_weight = {i: class_weights[i] for i in range(len(class_weights))})
    else:
        return SVC()

# %% [markdown]
# ## CrossValidations

# %%
from sklearn.model_selection import ShuffleSplit
n_splits = 10
cv = ShuffleSplit(n_splits=n_splits, random_state=42)

# %%
def eval_model(model, X_train, y_train, X_val, y_val):
    model.fit(X_train, y_train.flatten())
    y_pred = model.predict(X_val)
    acc = np.mean(y_pred.flatten() == y_val.flatten())
    return acc

# %%
reducers_dict = {"No reduction": mock,
                "PCA": pca,
                "UMAP": umap,
                "Autoencoder": autoencoder}
models = {"MLP": make_mlp, "KNC": make_knc, "RFC": make_rfc, "SCV": make_svc}

# def create_resultdict():
#     d = {"Unweighted": {"No reduction": [], "PCA": [], "UMAP": [], "Autoencoder": []}, 
#         "Weighted": {"No reduction": [], "PCA": [], "UMAP": [], "Autoencoder": []}}
#     return d

# %% [markdown]
# ## Model Comparisons

# %%
from tqdm import tqdm

eternal_counter = 0
for model_name in models.keys():
    print(model_name)
    ##### 1st Loop: Which Model do I use?
    model_init = models[model_name]
    quality_dict = {}#  create_resultdict()
    for reducer_name in reducers_dict:
        #### 2md Loop: Which dimension reduction tqchnique is used?
        reducer = reducers_dict[reducer_name]
        for i, (train_index, val_index) in tqdm(enumerate(cv.split(X)), desc = f"Reducer: {reducer_name}", total = n_splits):
            ##### 3rd Loop: Start Cross Validation
            X_train, y_train = X.iloc[train_index, :].to_numpy(), Y.iloc[train_index].to_numpy()
            X_val, y_val = X.iloc[val_index, :].to_numpy(), Y.iloc[val_index].to_numpy()
        
            for mode in ["Unweighted", "Weighted"]:#  quality_dict:
                ###### 4th Loop Once weighed, once unweighted
                reducer.fit(X_train)
                X_train_embedded = reducer.transform(X_train)
                X_val_embedded = reducer.transform(X_val)
                model = model_init(mode, in_features = X_train_embedded.shape[1])
                acc = eval_model(model, X_train_embedded, y_train, X_val_embedded, y_val)
                quality_dict[str(eternal_counter)] = {"Mode": mode, "Reducer": reducer_name, "Accuracy": acc, "CrossValEpoch": i+1}
                eternal_counter += 1


    quality_df = pd.DataFrame(quality_dict).transpose()
    fig = plt.figure(figsize = (8, 8))
    ax = fig.add_subplot()
    sns.barplot(quality_df, x = "Reducer", y = "Accuracy", hue = "Mode", errorbar = "sd")
    ax.set_title(model_name)
    plt.show()
        #### the quality dict has been filled with 10 entries per list for the specidied model and dimension reduction
# Out:
# MLP
# ...
# Reducer: Autoencoder: 100%|████████████████████████████████████████████████████████████| 10/10 [00:17<00:00,  1.71s/it]
# KNC
# ...
# Reducer: Autoencoder: 100%|████████████████████████████████████████████████████████████| 10/10 [00:03<00:00,  3.26it/s]
# RFC
# ...
# Reducer: Autoencoder: 100%|████████████████████████████████████████████████████████████| 10/10 [00:23<00:00,  2.35s/it]
# SCV
# ...
# Reducer: Autoencoder: 100%|████████████████████████████████████████████████████████████| 10/10 [00:11<00:00,  1.18s/it]

# %%
model_name
