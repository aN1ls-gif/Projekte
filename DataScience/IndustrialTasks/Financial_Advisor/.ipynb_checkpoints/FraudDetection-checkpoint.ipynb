# %% [markdown]
# Dataset creditcard.csv provided by Kaggle. For secutrity resons, it does not contain the original, but the 28 components of the PCA transformed data. Teh only untransformed columns are Time, Amount and Class

# %%
import numpy as np
import pandas as pd

credit_data = pd.read_csv("creditcard.txt")
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
np.any(credit_data.isna())
# Out:
# np.True_

# %%
np.sum(credit_data.isna(), axis = 0)
# Out:
# Time      0
# V1        0
# V2        0
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_data["Class"].describe()
# Out:
# count    177738.000000
# mean          0.002042
# std           0.045146
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: Class, dtype: float64

# %%
(np.sum(credit_data["Class"] == 0) / credit_data.shape[0]) * 100
# Out:
# np.float64(99.79520532916243)

# %% [markdown]
# Data is highly imbalanced. 99.8% of the datapoints belong to the 'not fraud' class. Just by always predicting a transaction as not fraudulent, our modul would have a 99.8% accuracy and would still be unreliable for the task at hand.

# %% [markdown]
# How to handle imbalanced data for a prediciton model? We could:
# 1. Undersampling: Reduce the number of entries in the majority class
# 2. Oversampling: Increase the number of entires in the minority class (for example generate new values based on the existing once. simplest approach would be duplication)
# 3. If possible for the ML model we choose, increase the weight (impact) the minority class has on the algorithm and/or decrease te weight of the majority class

# %%
credit_data.dropna(inplace = True)

# %%
from sklearn.model_selection import train_test_split
train_X, test_X, train_y, test_y = train_test_split(credit_data.drop(columns = ["Class"]), credit_data.loc[:, "Class"], test_size = 0.3, random_state = 42)

# %% [markdown]
# Steps:
# 1. Choose Models (k-NN, RandomForest)
# 3. Build CrossValidation Loop; use crossvall or shufflesplit
# 4. compare datasets and sampling techniques

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

crossval_dict = {}
crossval_dict["KNC"] = {}
crossval_dict["RFC"] = {}

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier

from imblearn.under_sampling import NearMiss
from imblearn.over_sampling import SMOTE

# %%
cv = ShuffleSplit(n_splits=10, test_size=0.3, random_state=0)
for i, (train_index, val_index) in enumerate(cv.split(train_X)):
    print(i+1)
    X_train, X_val = train_X.iloc[train_index, :], train_X.iloc[val_index, :]
    y_train, y_val = train_y.iloc[train_index], train_y.iloc[val_index]

    NM = NearMiss()
    X_under, y_under = NM.fit_resample(X_train, y_train)
    SM = SMOTE()
    X_over, y_over = SM.fit_resample(X_train, y_train)

    for name, data_X, data_y in [["Unmodified", X_train, y_train], ["Undersampled", X_under, y_under], ["Oversampled", X_over, y_over]]:
        print(name)
        print("KNN")
        model = KNeighborsClassifier(weights = "distance", n_neighbors=20)
        model.fit(data_X, data_y)
        y_pred = model.predict(X_val)
        acc = np.mean(y_pred == y_val.to_numpy().flatten())
        crossval_dict["KNC"][name] = crossval_dict["KNC"].get(name, []) + [acc]

        print("RFC")
        model = RandomForestClassifier(min_samples_leaf = 70, min_impurity_decrease = 1e-4, max_depth = 7)
        model.fit(data_X, data_y)
        y_pred = model.predict(X_val)
        acc = np.mean(y_pred == y_val.to_numpy().flatten())
        crossval_dict["RFC"][name] = crossval_dict["RFC"].get(name, []) + [acc]


    print("\n----------------------\n")
# Out:
# 1
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 2
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 3
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 4
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 5
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 6
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 7
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 8
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# 9
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
#
# ----------------------
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

outer_list = []
for modelname in crossval_dict:
    Model = crossval_dict[modelname]
    inner_list = []
    for method in crossval_dict[modelname]:
        inner_list.append(np.median(crossval_dict[modelname][method]))
    outer_list.append(inner_list)

rownames = list(crossval_dict.keys())
columnnames = list(crossval_dict[modelname].keys())

fig = plt.figure(figsize = (12, 8))
ax = fig.add_subplot()
sns.heatmap(np.array(outer_list), ax = ax, xticklabels = columnnames, yticklabels = rownames, annot = True, fmt = ".2%")
# ax.set_xticks([i for i in range(len(columnnames))], labels = columnnames)
# ax.set_yticks([i for i in range(len(rownames))], labels = rownames)
ax.set_title("Median validation accuracy for Models and Sampling techniques")
plt.show()

# %%
from sklearn.metrics import confusion_matrix

X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size = 0.1)
NM = NearMiss()
X_under, y_under = NM.fit_resample(X_train, y_train)
SM = SMOTE()
X_over, y_over = SM.fit_resample(X_train, y_train)

for name, data_X, data_y in [["Unmodified", X_train, y_train], ["Undersampled", X_under, y_under], ["Oversampled", X_over, y_over]]:
    print(name) 
    print("KNN")

    fig = plt.figure(figsize = (20, 10))
    
    
    model = KNeighborsClassifier(weights = "distance", n_neighbors=20)
    model.fit(data_X, data_y)
    y_pred = model.predict(test_X)
    cm = confusion_matrix(y_true = test_y.to_numpy(), y_pred = y_pred)
    cm = cm / np.sum(cm, axis = 1)[:, None] # I want to know the percentage of how much is correctly predicted
    ax = fig.add_subplot(1, 2, 1)
    sns.heatmap(cm, ax = ax, yticklabels = ["No Fraud", "Fraud"], xticklabels = ["No Fraud", "Fraud"], annot = True, fmt = ".2%")
    ax.set_ylabel("True Class")
    ax.set_xlabel("Predicted Class")
    ax.set_title("KNN")

    print("RFC")
    model = RandomForestClassifier(min_samples_leaf = 70, min_impurity_decrease = 1e-4, max_depth = 7)
    model.fit(data_X, data_y)
    y_pred = model.predict(test_X)
    cm = confusion_matrix(y_true = test_y.to_numpy(), y_pred = y_pred)
    cm = cm / np.sum(cm, axis = 1)[:, None]# I want to know the percentage of how much is correctly predicted
    ax = fig.add_subplot(1, 2, 2)
    sns.heatmap(cm, ax = ax, yticklabels = ["No Fraud", "Fraud"], xticklabels = ["No Fraud", "Fraud"], annot = True, fmt = ".2%")
    ax.set_ylabel("True Class")
    ax.set_xlabel("Predicted Class")
    ax.set_title("RFC")

    fig.suptitle(f"Confusion matrices for sampling technique '{name}'")
    plt.show()


print("\n----------------------\n")
# Out:
# Unmodified
# KNN
# RFC
# Undersampled
# KNN
# RFC
# Oversampled
# KNN
# RFC
# ----------------------
