# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

data_dir = "Logs/CSVLogger"
subdir_name = "version_"
df = []
for i in os.listdir(data_dir):
    if i.startswith(subdir_name):
        df.append(pd.read_csv(f"{data_dir}/{i}/metrics.csv"))

df = pd.concat(df, axis = 0)
df
# Out:
#     epoch  step  train_acc  train_loss  val_acc  val_acc_just_0  \
# 0       0    49   0.626667    0.701813      NaN             NaN
# 1       0    99   0.520000    0.771153      NaN             NaN
# 2       0   149   0.653333    0.661771      NaN             NaN
# 3       0   199   0.626667    0.670631      NaN             NaN
# 4       0   249   0.626667    0.687397      NaN             NaN
# 5       0   299   0.693333    0.654161      NaN             NaN
# 6       0   299        NaN         NaN   0.6488           0.504
# 7       1   349   0.653333    0.640096      NaN             NaN
# 8       1   399   0.586667    0.665289      NaN             NaN
# 9       1   449   0.706667    0.648656      NaN             NaN
# 10      1   499   0.746667    0.604904      NaN             NaN
# 11      1   549   0.666667    0.639118      NaN             NaN
# 12      1   599   0.666667    0.666692      NaN             NaN
# 13      1   599        NaN         NaN   0.6600           0.504
# 14      2   649   0.706667    0.589066      NaN             NaN
# 15      2   699   0.560000    0.723576      NaN             NaN
# 16      2   749   0.680000    0.616624      NaN             NaN
# 17      2   799   0.613333    0.645079      NaN             NaN
# 18      2   849   0.733333    0.594530      NaN             NaN
# 19      2   899   0.706667    0.609754      NaN             NaN
# 20      2   899        NaN         NaN   0.7012           0.504
# 21      3   949   0.680000    0.679634      NaN             NaN
# 22      3   999   0.826667    0.547406      NaN             NaN
# 23      3  1049   0.693333    0.665089      NaN             NaN
# 24      3  1099   0.720000    0.633937      NaN             NaN
# 25      3  1149   0.733333    0.593558      NaN             NaN
# 26      3  1199   0.733333    0.595740      NaN             NaN
# 27      3  1199        NaN         NaN   0.6912           0.504
# 28      4  1249   0.746667    0.563380      NaN             NaN
# 29      4  1299   0.773333    0.581573      NaN             NaN
# 30      4  1349   0.706667    0.608964      NaN             NaN
# 31      4  1399   0.786667    0.575455      NaN             NaN
# 32      4  1449   0.773333    0.598670      NaN             NaN
# 33      4  1499   0.760000    0.569537      NaN             NaN
# 34      4  1499        NaN         NaN   0.7188           0.504
# 35      5  1549   0.693333    0.632602      NaN             NaN
# 36      5  1599   0.600000    0.674188      NaN             NaN
# 37      5  1649   0.706667    0.603422      NaN             NaN
# 38      5  1699   0.666667    0.663103      NaN             NaN
# 39      5  1749   0.666667    0.637962      NaN             NaN
#
#     val_acc_just_1  val_loss
# 0              NaN       NaN
# 1              NaN       NaN
# 2              NaN       NaN
# 3              NaN       NaN
# 4              NaN       NaN
# 5              NaN       NaN
# 6            0.496  0.673267
# 7              NaN       NaN
# 8              NaN       NaN
# 9              NaN       NaN
# 10             NaN       NaN
# 11             NaN       NaN
# 12             NaN       NaN
# 13           0.496  0.659642
# 14             NaN       NaN
# 15             NaN       NaN
# 16             NaN       NaN
# 17             NaN       NaN
# 18             NaN       NaN
# 19             NaN       NaN
# 20           0.496  0.623220
# 21             NaN       NaN
# 22             NaN       NaN
# 23             NaN       NaN
# 24             NaN       NaN
# 25             NaN       NaN
# 26             NaN       NaN
# 27           0.496  0.637024
# 28             NaN       NaN
# 29             NaN       NaN
# 30             NaN       NaN
# 31             NaN       NaN
# 32             NaN       NaN
# 33             NaN       NaN
# 34           0.496  0.612944
# 35             NaN       NaN
# 36             NaN       NaN
# 37             NaN       NaN
# 38             NaN       NaN
# 39             NaN       NaN

# %%
df_means = df.groupby("epoch").mean()
df_stds = df.groupby("epoch").std()

# %%
fig = plt.figure(figsize = (15, 5))
ax = fig.add_subplot(1, 2, 1)
ax.errorbar(x = list(df_means.index), y = df_means.train_loss, yerr = df_stds.train_loss, label = "train_loss")
ax.plot(list(df_means.index), df_means.val_loss, label = "val_loss")
ax.legend()
ax.set_xlabel("Epoch")
ax.set_ylabel("Cross Entropy Loss")

ax = fig.add_subplot(1, 2, 2)
ax.errorbar(x = list(df_means.index), y = df_means.train_acc*100, yerr = df_stds.train_acc*100, label = "train_acc")
ax.plot(list(df_means.index), df_means.val_acc*100, label = "val_acc")
ax.legend()
ax.set_xlabel("Epoch")
ax.set_ylabel("Accuracy [%]")

plt.show()
